# %%
import os

if "MJPYTHON_LIBPYTHON" in os.environ:
    print("✅ Success: Running under the MuJoCo macOS thread launcher!")
    print(f"Bound Library: {os.environ.get('MJPYTHON_LIBPYTHON')}")
else:
    print("❌ Warning: Running on vanilla Python (MuJoCo rendering might crash).")
# Out:
# ✅ Success: Running under the MuJoCo macOS thread launcher!
# Bound Library: /Users/taydakov/miniforge3/envs/lerobot/bin/python3.12
